# %%
import pandas as pd
import csv
import datetime as dt
from sqlalchemy import create_engine

# %% [markdown]
# # Read Mass 2016 and Transform Database

# %%
csv_file_1="Resources/mass_2016 (1).csv"
mass_1971_1981 = pd.read_csv(csv_file_1)
mass_1971_1981.head()
# Out:
#    CaseID                           Title                Location  \
# 0     1.0   University of Texas at Austin           Austin, Texas
# 1     2.0      Rose-Mar College of Beauty           Mesa, Arizona
# 2     3.0    New Orleans Police Shootings  New Orleans, Louisiana
# 3     4.0  Clara Barton Elementary School       Chicago, Illinois
# 4     5.0               Olean High School         Olean, New York
#
#           City      State   Latitude   Longitude  Number of Victim Fatalities  \
# 0       Austin      Texas  30.198887  -97.844159                         16.0
# 1         Mesa    Arizona  33.422687 -111.816320                          5.0
# 2  New Orleans  Louisiana  30.068724  -89.931474                          9.0
# 3      Chicago   Illinois  41.839280  -87.688181                          1.0
# 4        Olean   New York  42.081854  -78.432139                          3.0
#
#    Total Number of Fatalities  Number of Victims Injured  ...  \
# ...

# %%
drop_mass=mass_1971_1981[["Title","Location","Number of Victim Fatalities","Number of Victims Injured",
                          "Total Number of Victims","Date","Average Shooter Age","Shooter Sex","Shooter Race"]].copy()
drop_mass.head()
# Out:
#                             Title                Location  \
# 0   University of Texas at Austin           Austin, Texas
# 1      Rose-Mar College of Beauty           Mesa, Arizona
# 2    New Orleans Police Shootings  New Orleans, Louisiana
# 3  Clara Barton Elementary School       Chicago, Illinois
# 4               Olean High School         Olean, New York
#
#    Number of Victim Fatalities  Number of Victims Injured  \
# 0                         16.0                       32.0
# 1                          5.0                        1.0
# 2                          9.0                       13.0
# 3                          1.0                        3.0
# 4                          3.0                        7.0
#
#    Total Number of Victims        Date Average Shooter Age Shooter Sex  \
# 0                     48.0    8/1/1966                  25        Male
# 1                      6.0  11/12/1966                  18        Male
# ...

# %%
mass_1971_1981_rename=drop_mass.rename(columns={"Title":"Shooting_Case","Location":"Shooting_Location",
                                                "Number of Victim Fatalities":"Fatalities",
                                                "Number of Victims Injured":"Injured",
                                                "Total Number of Victims":"Total_Victims",
                                                "Date":"Shooting_Date",
                                                "Average Shooter Age":"Shooter_Age",
                                                "Shooter Sex":"Shooter_Gender",
                                                "Shooter Race":"Shooter_Race"})
mass_1971_1981_rename.head()
# Out:
#                     Shooting_Case       Shooting_Location  Fatalities  \
# 0   University of Texas at Austin           Austin, Texas        16.0
# 1      Rose-Mar College of Beauty           Mesa, Arizona         5.0
# 2    New Orleans Police Shootings  New Orleans, Louisiana         9.0
# 3  Clara Barton Elementary School       Chicago, Illinois         1.0
# 4               Olean High School         Olean, New York         3.0
#
#    Injured  Total_Victims Shooting_Date Shooter_Age Shooter_Gender  \
# 0     32.0           48.0      8/1/1966          25           Male
# 1      1.0            6.0    11/12/1966          18           Male
# 2     13.0           22.0      12/31/72          23           Male
# 3      3.0            4.0       1/17/74          14           Male
# 4      7.0           10.0      12/30/74          17           Male
#
#                           Shooter_Race
# 0  White American or European American
# 1  White American or European American
# ...

# %%
mass_1971_1981_rename['Shooting_Date'] = pd.to_datetime(mass_1971_1981_rename['Shooting_Date'])

# %%
mass_1971_1981_rename['Shooting_Date'] = mass_1971_1981_rename['Shooting_Date'].dt.strftime('%Y-%m-%d')
mass_1971_1981_rename.head()
# Out:
#                     Shooting_Case       Shooting_Location  Fatalities  \
# 0   University of Texas at Austin           Austin, Texas        16.0
# 1      Rose-Mar College of Beauty           Mesa, Arizona         5.0
# 2    New Orleans Police Shootings  New Orleans, Louisiana         9.0
# 3  Clara Barton Elementary School       Chicago, Illinois         1.0
# 4               Olean High School         Olean, New York         3.0
#
#    Injured  Total_Victims Shooting_Date Shooter_Age Shooter_Gender  \
# 0     32.0           48.0    1966-08-01          25           Male
# 1      1.0            6.0    1966-11-12          18           Male
# 2     13.0           22.0    1972-12-31          23           Male
# 3      3.0            4.0    1974-01-17          14           Male
# 4      7.0           10.0    1974-12-30          17           Male
#
#                           Shooter_Race
# 0  White American or European American
# 1  White American or European American
# ...

# %%
start_date = "1971-1-1"
end_date = "1981-1-31"

after_start_date = mass_1971_1981_rename["Shooting_Date"] >= start_date
before_end_date = mass_1971_1981_rename["Shooting_Date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates = mass_1971_1981_rename.loc[between_two_dates]

filtered_dates.reset_index(inplace=True)
final_1971_1981_df=filtered_dates.drop(columns=['index'])
final_1971_1981_df
# Out:
#                           Shooting_Case         Shooting_Location  Fatalities  \
# 0          New Orleans Police Shootings    New Orleans, Louisiana         9.0
# 1        Clara Barton Elementary School         Chicago, Illinois         1.0
# 2                     Olean High School           Olean, New York         3.0
# 3  Los Angeles Computer Learning Center   Los Angeles, California         1.0
# 4                   Cal State Fullerton     Fullerton, California         7.0
# 5    Grover Cleveland Elementary School     San Diego, California         2.0
# 6          University of South Carolina  Columbia, South Carolina         2.0
#
#    Injured  Total_Victims Shooting_Date Shooter_Age Shooter_Gender  \
# 0     13.0           22.0    1972-12-31          23           Male
# 1      3.0            4.0    1974-01-17          14           Male
# 2      7.0           10.0    1974-12-30          17           Male
# 3      7.0            8.0    1976-02-19          18           Male
# ...

# %%
final_1971_1981_df[['City','State']]=final_1971_1981_df.Shooting_Location.str.split(',',expand=True)
print(final_1971_1981_df)
# Out:
#                           Shooting_Case         Shooting_Location  Fatalities  \
# 0          New Orleans Police Shootings    New Orleans, Louisiana         9.0
# 1        Clara Barton Elementary School         Chicago, Illinois         1.0
# 2                     Olean High School           Olean, New York         3.0
# 3  Los Angeles Computer Learning Center   Los Angeles, California         1.0
# 4                   Cal State Fullerton     Fullerton, California         7.0
# 5    Grover Cleveland Elementary School     San Diego, California         2.0
# 6          University of South Carolina  Columbia, South Carolina         2.0
#
#    Injured  Total_Victims Shooting_Date Shooter_Age Shooter_Gender  \
# 0     13.0           22.0    1972-12-31          23           Male
# 1      3.0            4.0    1974-01-17          14           Male
# 2      7.0           10.0    1974-12-30          17           Male
# 3      7.0            8.0    1976-02-19          18           Male
# ...

# %%
new_df=pd.DataFrame(final_1971_1981_df)
new_df
# Out:
#                           Shooting_Case         Shooting_Location  Fatalities  \
# 0          New Orleans Police Shootings    New Orleans, Louisiana         9.0
# 1        Clara Barton Elementary School         Chicago, Illinois         1.0
# 2                     Olean High School           Olean, New York         3.0
# 3  Los Angeles Computer Learning Center   Los Angeles, California         1.0
# 4                   Cal State Fullerton     Fullerton, California         7.0
# 5    Grover Cleveland Elementary School     San Diego, California         2.0
# 6          University of South Carolina  Columbia, South Carolina         2.0
#
#    Injured  Total_Victims Shooting_Date Shooter_Age Shooter_Gender  \
# 0     13.0           22.0    1972-12-31          23           Male
# 1      3.0            4.0    1974-01-17          14           Male
# 2      7.0           10.0    1974-12-30          17           Male
# 3      7.0            8.0    1976-02-19          18           Male
# ...

# %%
other_df=new_df.drop(columns=['Shooting_Location'])
other_df
# Out:
#                           Shooting_Case  Fatalities  Injured  Total_Victims  \
# 0          New Orleans Police Shootings         9.0     13.0           22.0
# 1        Clara Barton Elementary School         1.0      3.0            4.0
# 2                     Olean High School         3.0      7.0           10.0
# 3  Los Angeles Computer Learning Center         1.0      7.0            8.0
# 4                   Cal State Fullerton         7.0      2.0            9.0
# 5    Grover Cleveland Elementary School         2.0      9.0           11.0
# 6          University of South Carolina         2.0      5.0            7.0
#
#   Shooting_Date Shooter_Age Shooter_Gender  \
# 0    1972-12-31          23           Male
# 1    1974-01-17          14           Male
# 2    1974-12-30          17           Male
# 3    1976-02-19          18           Male
# 4    1976-07-12          37           Male
# 5    1979-01-29          16         Female
# 6    1979-10-06          19           Male
#
# ...

# %%
mass_shooting_1971_1981=other_df[["Shooting_Case","Shooting_Date","City","State","Fatalities","Injured",
                                  "Total_Victims","Shooter_Age","Shooter_Gender","Shooter_Race"]]
mass_shooting_1971_1981
# Out:
#                           Shooting_Case Shooting_Date         City  \
# 0          New Orleans Police Shootings    1972-12-31  New Orleans
# 1        Clara Barton Elementary School    1974-01-17      Chicago
# 2                     Olean High School    1974-12-30        Olean
# 3  Los Angeles Computer Learning Center    1976-02-19  Los Angeles
# 4                   Cal State Fullerton    1976-07-12    Fullerton
# 5    Grover Cleveland Elementary School    1979-01-29    San Diego
# 6          University of South Carolina    1979-10-06     Columbia
#
#              State  Fatalities  Injured  Total_Victims Shooter_Age  \
# 0        Louisiana         9.0     13.0           22.0          23
# 1         Illinois         1.0      3.0            4.0          14
# 2         New York         3.0      7.0           10.0          17
# 3       California         1.0      7.0            8.0          18
# 4       California         7.0      2.0            9.0          37
# ...

# %% [markdown]
# # Read Mother Jones DB and Transform Database

# %%
csv_file_2="Resources/Mother Jones - Mass Shootings Database, 1982 - 2019 (3).csv"
mass_1982_2021 = pd.read_csv(csv_file_2)
mass_1982_2021.head()
# Out:
#                                 case                location      date  \
# 0  Sacramento County church shooting  Sacramento, California   2/28/22
# 1        Oxford High School shooting        Oxford, Michigan  11/30/21
# 2              San Jose VTA shooting    San Jose, California   5/26/21
# 3           FedEx warehouse shooting   Indianapolis, Indiana   4/15/21
# 4     Orange office complex shooting      Orange, California   3/31/21
#
#                                              summary  fatalities  injured  \
# 0  "A man believed to be meeting his three childr...           4        0
# 1  Ethan Crumbley, a 15-year-old student at Oxfor...           4        7
# 2  Samuel Cassidy, 57, a Valley Transportation Au...           9        0
# 3  Brandon Scott Hole, 19, opened fire around 11 ...           8        7
# 4  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4        1
#
#    total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# ...

# %%
drop_mass_2 = mass_1982_2021[['case','location','date','fatalities','injured','total_victims',
                              'age_of_shooter','race','gender']]
drop_mass_2.head()
# Out:
#                                 case                location      date  \
# 0  Sacramento County church shooting  Sacramento, California   2/28/22
# 1        Oxford High School shooting        Oxford, Michigan  11/30/21
# 2              San Jose VTA shooting    San Jose, California   5/26/21
# 3           FedEx warehouse shooting   Indianapolis, Indiana   4/15/21
# 4     Orange office complex shooting      Orange, California   3/31/21
#
#    fatalities  injured  total_victims age_of_shooter   race gender
# 0           4        0              4              -      -      M
# 1           4        7             11             15      -      M
# 2           9        0              9             57      -      M
# 3           8        7             15             19  White      M
# 4           4        1              5              -      -      M

# %%
mass_1982_2021_rename=drop_mass_2.rename(columns={"case":"Shooting_Case",
                                                  "location":"Shooting_Location",
                                                  "date":"Shooting_Date",
                                                  "fatalities":"Fatalities",
                                                  "injured":"Injured",
                                                  "total_victims":"Total_Victims",
                                                  "age_of_shooter":"Shooter_Age",
                                                  "race":"Shooter_Race",
                                                  "gender":"Shooter_Gender"})
mass_1982_2021_rename.head()
# Out:
#                        Shooting_Case       Shooting_Location Shooting_Date  \
# 0  Sacramento County church shooting  Sacramento, California       2/28/22
# 1        Oxford High School shooting        Oxford, Michigan      11/30/21
# 2              San Jose VTA shooting    San Jose, California       5/26/21
# 3           FedEx warehouse shooting   Indianapolis, Indiana       4/15/21
# 4     Orange office complex shooting      Orange, California       3/31/21
#
#    Fatalities  Injured  Total_Victims Shooter_Age Shooter_Race Shooter_Gender
# 0           4        0              4           -            -              M
# 1           4        7             11          15            -              M
# 2           9        0              9          57            -              M
# 3           8        7             15          19        White              M
# 4           4        1              5           -            -              M

# %%
mass_1982_2021_rename['Shooting_Date'] = pd.to_datetime(mass_1982_2021_rename['Shooting_Date'])

# %%
mass_1982_2021_rename['Shooting_Date'] = mass_1982_2021_rename['Shooting_Date'].dt.strftime('%Y-%m-%d')
mass_1982_2021_rename.head()
# Out:
#                        Shooting_Case       Shooting_Location Shooting_Date  \
# 0  Sacramento County church shooting  Sacramento, California    2022-02-28
# 1        Oxford High School shooting        Oxford, Michigan    2021-11-30
# 2              San Jose VTA shooting    San Jose, California    2021-05-26
# 3           FedEx warehouse shooting   Indianapolis, Indiana    2021-04-15
# 4     Orange office complex shooting      Orange, California    2021-03-31
#
#    Fatalities  Injured  Total_Victims Shooter_Age Shooter_Race Shooter_Gender
# 0           4        0              4           -            -              M
# 1           4        7             11          15            -              M
# 2           9        0              9          57            -              M
# 3           8        7             15          19        White              M
# 4           4        1              5           -            -              M

# %%
mass_1982_2021_rename[['City','State']]=mass_1982_2021_rename.Shooting_Location.str.split(',',expand=True)
print(mass_1982_2021_rename)
# Out:
#                              Shooting_Case       Shooting_Location  \
# 0        Sacramento County church shooting  Sacramento, California
# 1              Oxford High School shooting        Oxford, Michigan
# 2                    San Jose VTA shooting    San Jose, California
# 3                 FedEx warehouse shooting   Indianapolis, Indiana
# 4           Orange office complex shooting      Orange, California
# ..                                     ...                     ...
# 121        Shopping centers spree killings       Palm Bay, Florida
# 122  United States Postal Service shooting        Edmond, Oklahoma
# 123         San Ysidro McDonald's massacre  San Ysidro, California
# 124              Dallas nightclub shooting           Dallas, Texas
# 125                  Welding shop shooting          Miami, Florida
#
#     Shooting_Date  Fatalities  Injured  Total_Victims Shooter_Age  \
# 0      2022-02-28           4        0              4           -
# ...

# %%
new_df_2=pd.DataFrame(mass_1982_2021_rename)
new_df_2
# Out:
#                              Shooting_Case       Shooting_Location  \
# 0        Sacramento County church shooting  Sacramento, California
# 1              Oxford High School shooting        Oxford, Michigan
# 2                    San Jose VTA shooting    San Jose, California
# 3                 FedEx warehouse shooting   Indianapolis, Indiana
# 4           Orange office complex shooting      Orange, California
# ..                                     ...                     ...
# 121        Shopping centers spree killings       Palm Bay, Florida
# 122  United States Postal Service shooting        Edmond, Oklahoma
# 123         San Ysidro McDonald's massacre  San Ysidro, California
# 124              Dallas nightclub shooting           Dallas, Texas
# 125                  Welding shop shooting          Miami, Florida
#
#     Shooting_Date  Fatalities  Injured  Total_Victims Shooter_Age  \
# 0      2022-02-28           4        0              4           -
# ...

# %%
other_df_2 = new_df_2.drop(columns=['Shooting_Location'])
other_df_2
# Out:
#                              Shooting_Case Shooting_Date  Fatalities  Injured  \
# 0        Sacramento County church shooting    2022-02-28           4        0
# 1              Oxford High School shooting    2021-11-30           4        7
# 2                    San Jose VTA shooting    2021-05-26           9        0
# 3                 FedEx warehouse shooting    2021-04-15           8        7
# 4           Orange office complex shooting    2021-03-31           4        1
# ..                                     ...           ...         ...      ...
# 121        Shopping centers spree killings    1987-04-23           6       14
# 122  United States Postal Service shooting    1986-08-20          15        6
# 123         San Ysidro McDonald's massacre    1984-07-18          22       19
# 124              Dallas nightclub shooting    1984-06-29           6        1
# 125                  Welding shop shooting    1982-08-20           8        3
#
# ...

# %%
mass_shooting_1982_2021=other_df_2[["Shooting_Case","Shooting_Date","City","State","Fatalities",
                                    "Injured","Total_Victims","Shooter_Age","Shooter_Gender","Shooter_Race"]]
mass_shooting_1982_2021
# Out:
#                              Shooting_Case Shooting_Date          City  \
# 0        Sacramento County church shooting    2022-02-28    Sacramento
# 1              Oxford High School shooting    2021-11-30        Oxford
# 2                    San Jose VTA shooting    2021-05-26      San Jose
# 3                 FedEx warehouse shooting    2021-04-15  Indianapolis
# 4           Orange office complex shooting    2021-03-31        Orange
# ..                                     ...           ...           ...
# 121        Shopping centers spree killings    1987-04-23      Palm Bay
# 122  United States Postal Service shooting    1986-08-20        Edmond
# 123         San Ysidro McDonald's massacre    1984-07-18    San Ysidro
# 124              Dallas nightclub shooting    1984-06-29        Dallas
# 125                  Welding shop shooting    1982-08-20         Miami
#
#            State  Fatalities  Injured  Total_Victims Shooter_Age  \
# ...

# %% [markdown]
# # Concat Databases

# %%
mass_shootings = pd.concat([mass_shooting_1971_1981, mass_shooting_1982_2021], axis=0)
mass_shootings
# Out:
#                              Shooting_Case Shooting_Date         City  \
# 0             New Orleans Police Shootings    1972-12-31  New Orleans
# 1           Clara Barton Elementary School    1974-01-17      Chicago
# 2                        Olean High School    1974-12-30        Olean
# 3     Los Angeles Computer Learning Center    1976-02-19  Los Angeles
# 4                      Cal State Fullerton    1976-07-12    Fullerton
# ..                                     ...           ...          ...
# 121        Shopping centers spree killings    1987-04-23     Palm Bay
# 122  United States Postal Service shooting    1986-08-20       Edmond
# 123         San Ysidro McDonald's massacre    1984-07-18   San Ysidro
# 124              Dallas nightclub shooting    1984-06-29       Dallas
# 125                  Welding shop shooting    1982-08-20        Miami
#
#            State  Fatalities  Injured  Total_Victims Shooter_Age  \
# ...

# %%
mass_shootings=mass_shootings.sort_values(['Shooting_Date'])
mass_shootings
# Out:
#                            Shooting_Case Shooting_Date          City  \
# 0           New Orleans Police Shootings    1972-12-31   New Orleans
# 1         Clara Barton Elementary School    1974-01-17       Chicago
# 2                      Olean High School    1974-12-30         Olean
# 3   Los Angeles Computer Learning Center    1976-02-19   Los Angeles
# 4                    Cal State Fullerton    1976-07-12     Fullerton
# ..                                   ...           ...           ...
# 4         Orange office complex shooting    2021-03-31        Orange
# 3               FedEx warehouse shooting    2021-04-15  Indianapolis
# 2                  San Jose VTA shooting    2021-05-26      San Jose
# 1            Oxford High School shooting    2021-11-30        Oxford
# 0      Sacramento County church shooting    2022-02-28    Sacramento
#
#           State  Fatalities  Injured  Total_Victims Shooter_Age  \
# 0     Louisiana         9.0     13.0           22.0          23
# ...

# %%
mass_shootings_db=mass_shootings.reset_index()
final_mass_shootings=mass_shootings_db.drop(columns=['index'])
final_mass_shootings
# Out:
#                             Shooting_Case Shooting_Date          City  \
# 0            New Orleans Police Shootings    1972-12-31   New Orleans
# 1          Clara Barton Elementary School    1974-01-17       Chicago
# 2                       Olean High School    1974-12-30         Olean
# 3    Los Angeles Computer Learning Center    1976-02-19   Los Angeles
# 4                     Cal State Fullerton    1976-07-12     Fullerton
# ..                                    ...           ...           ...
# 128        Orange office complex shooting    2021-03-31        Orange
# 129              FedEx warehouse shooting    2021-04-15  Indianapolis
# 130                 San Jose VTA shooting    2021-05-26      San Jose
# 131           Oxford High School shooting    2021-11-30        Oxford
# 132     Sacramento County church shooting    2022-02-28    Sacramento
#
#            State  Fatalities  Injured  Total_Victims Shooter_Age  \
# ...

# %% [markdown]
# # Connection to SQL

# %%
connection_string = "postgres:postgres@localhost:5432/mass_shootings"
engine = create_engine(f'postgresql://{connection_string}')

# %%
final_mass_shootings.to_sql(name='mass_shootings_1971_2021', con=engine, if_exists='append', index=True)
